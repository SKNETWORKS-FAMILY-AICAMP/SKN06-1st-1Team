# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic' # windows
matplotlib.rcParams['font.size'] = 15 # 글자 크기
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
hydrogen_car = pd.read_csv(r"C:\Project\data\hydrogen_car.csv")
vehicle_registration = pd.read_csv(r"C:\Project\data\vehicle_registration.csv")

hydrogen_car.head(), vehicle_registration.head()
# Out:
# (       증가량      계    년도
#  0      NaN    893  2018
#  1   4190.0   5083  2019
#  2   5823.0  10906  2020
#  3   8498.0  19404  2021
#  4  10219.0  29623  2022,
#          증가량           계    년도
#  0       NaN  17,663,188  2018
#  1  408535.0  18,071,723  2019
#  2  614847.0  18,686,570  2020
#  3  481692.0  19,168,262  2021
#  4  479713.0  19,647,975  2022)

# %%
plt.figure(figsize=(10, 6))

# 수소차 증가량 그래프
plt.plot(hydrogen_car['년도'], hydrogen_car['증가량'], marker='o', label='Hydrogen Car 증가량')

# 차량 등록 증가량 그래프
plt.plot(vehicle_registration['년도'], vehicle_registration['증가량'], marker='s', label='Vehicle Registration 증가량')

# 그래프 설정
plt.xlabel('년도')
plt.ylabel('증가량')
plt.title('년도별 수소차와 차량 등록 증가량')
plt.legend()
plt.grid(True)
plt.show()
